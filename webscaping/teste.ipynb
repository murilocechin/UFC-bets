# %%
import ufc_scrap as ufc
import numpy as np

# %%
df_events = ufc.get_events()

df_events
# Out:
# WARNING:Webscraping Realizado
#     event_id                                            event       date  \
# 0    EVE0664               UFC Fight Night: Fiziev vs. Gamrot 2023-09-23
# 1    EVE0663         UFC Fight Night: Grasso vs. Shevchenko 2 2023-09-16
# 2    EVE0662                 UFC 293: Adesanya vs. Strickland 2023-09-09
# 3    EVE0661                 UFC Fight Night: Gane vs. Spivac 2023-09-02
# 4    EVE0660  UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26
# ..       ...                                              ...        ...
# 659  EVE0005                       UFC 6: Clash of the Titans 1995-07-14
# 660  EVE0004                   UFC 5: The Return of the Beast 1995-04-07
# 661  EVE0003                   UFC 4: Revenge of the Warriors 1994-12-16
# 662  EVE0002                        UFC 3: The American Dream 1994-09-09
# 663  EVE0001                                UFC 2: No Way Out 1994-03-11
#
#           city            state    country
# ...

# %%
df_fights = ufc.get_fights()

df_fights
# Out:
# WARNING:Webscraping não realizado
#      event_id       weight_class   w/l              fighter1  \
# 0     EVE0663  Women's Flyweight  draw          Alexa Grasso
# 1     EVE0663       Welterweight   win  Jack Della Maddalena
# 2     EVE0663       Bantamweight   win        Raul Rosas Jr.
# 3     EVE0663        Lightweight   win      Daniel Zellhuber
# 4     EVE0663      Featherweight   win           Kyle Nelson
# ...       ...                ...   ...                   ...
# 7335  EVE0001        Open Weight   win          Orlando Wiet
# 7336  EVE0001        Open Weight   win         Frank Hamaker
# 7337  EVE0001        Open Weight   win         Johnny Rhodes
# 7338  EVE0001        Open Weight   win         Patrick Smith
# 7339  EVE0001        Open Weight   win          Scott Morris
#
#                   fighter2 kd_fighter1 kd_fighter2 str_fighter1 str_fighter2  \
# 0     Valentina Shevchenko           1           0           84           80
# ...

# %%
df_fighters = ufc.get_fighters()

df_fighters
# Out:
# WARNING:Webscraping não realizado
#         First        Last      Nickname    Stance  Belt  height   reach  \
# 0         Tom       Aaron           NaN       NaN   NaN     NaN     NaN
# 1       Danny      Abbadi  The Assassin  Orthodox   NaN  180.34     NaN
# 2     Nariman     Abbasov     Bayraktar  Orthodox   NaN  172.72  167.64
# 3       David      Abbott          Tank    Switch   NaN  182.88     NaN
# 4       Hamdy  Abdelwahab    The Hammer  Southpaw   NaN  187.96  182.88
# ...       ...         ...           ...       ...   ...     ...     ...
# 4104     Dave    Zitanick           NaN       NaN   NaN     NaN     NaN
# 4105     Alex      Zuniga           NaN       NaN   NaN     NaN     NaN
# 4106   George      Zuniga           NaN       NaN   NaN  175.26     NaN
# 4107    Allan      Zuniga         Tigre  Orthodox   NaN  170.18  177.80
# 4108   Virgil     Zwicker        RezDog       NaN   NaN  187.96  187.96
#
#        weight  win  lose  draw  total_fights fighters_id
# ...
