# %% [markdown]
# # <center>**Notebook get_events()**</center>

# %% [markdown]
# Notebook em jupyter que descreve a função `get_events()` do scrip ufc_scap() desde o webscraping até os tratamentos realizados para gerar o data frame final.

# %% [markdown]
# ### Bibliotecas utilizadas

# %%
# importando bibliotecas utilizadas no projeto
# Webscraping
import requests 
from bs4 import BeautifulSoup

# Manipulação de dados
import pandas as pd
import numpy as np

# %% [markdown]
# ## Webscraping
#
# O webcraping realizado nesta função retorna o html da tabela para transformação em dataframe.

# %%
# Iniciando função
def get_events():
    """
        Função que retorna a tabela de eventos realizados no ufc em formato html
    """
    # Link de acesso para pagina
    URL = "http://www.ufcstats.com/statistics/events/completed?page=all"


    # Realizando o request para o site 

    response = requests.get(URL)
    response.raise_for_status()

    # Obtendo pagina completa em html
    soup = BeautifulSoup(response.content, "html.parser")

    # Encontrando a tabela com a classe especificada

    table = soup.find("table", class_="b-statistics__table-events")

    return(table)

# %% [markdown]
# Nesta parte do código estamos obtendo a tabela em formato html.

# %%
# Mostrando resultado
tabela = get_events()

type(tabela)
# Out:
# bs4.element.Tag

# %%
# Visualizando resultado
tabela
# Out:
# <table class="b-statistics__table-events">
# <thead class="b-statistics__table-caption">
# <tr class="b-statistics__table-row">
# <th class="b-statistics__table-col">
#                   Name/date
#                 </th>
# <th class="b-statistics__table-col">
#                   Location
#                 </th>
# </tr>
# </thead>
# <tbody>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col_type_clear"></td>
# </tr>
# <tr class="b-statistics__table-row_type_first">
# <td class="b-statistics__table-col">
# <img class="b-statistics__icon" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/next.png">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_white" href="http://www.ufcstats.com/event-details/ece280745f8727b8">
#                           UFC 293: Adesanya vs. Strickland
#                         </a>
# <span class="b-statistics__date">
#                           September 09, 2023
#                         </span>
# </i>
# </img></td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Sydney, New South Wales, Australia
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/ef61d9f5176b3200">
#                           UFC Fight Night: Gane vs. Spivac
#                         </a>
# <span class="b-statistics__date">
#                           September 02, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Paris, Ile-de-France, France
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/89a407032911e27e">
#                           UFC Fight Night: Holloway vs. The Korean Zombie
#                         </a>
# <span class="b-statistics__date">
#                           August 26, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Kallang, Singapore
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/2719f300b0439039">
#                           UFC 292: Sterling vs. O'Malley
#                         </a>
# <span class="b-statistics__date">
#                           August 19, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Boston, Massachusetts, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/d2fa318f34d0aadc">
#                           UFC Fight Night: Luque vs. Dos Anjos
#                         </a>
# <span class="b-statistics__date">
#                           August 12, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/6f81b6de2557739a">
#                           UFC Fight Night: Sandhagen vs. Font
#                         </a>
# <span class="b-statistics__date">
#                           August 05, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Nashville, Tennessee, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/ccd58ff71e260ed5">
#                           UFC 291: Poirier vs. Gaethje 2
#                         </a>
# <span class="b-statistics__date">
#                           July 29, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Salt Lake City, Utah, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1174782eacde9b0c">
#                           UFC Fight Night: Aspinall vs. Tybura
#                         </a>
# <span class="b-statistics__date">
#                           July 22, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     London, England, United Kingdom
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/c9885b1b7c7055a0">
#                           UFC Fight Night: Holm vs. Bueno Silva
#                         </a>
# <span class="b-statistics__date">
#                           July 15, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/6085ceb59087514b">
#                           UFC 290: Volkanovski vs. Rodriguez
#                         </a>
# <span class="b-statistics__date">
#                           July 08, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/e9e1acc96536bb4f">
#                           UFC Fight Night: Strickland vs. Magomedov
#                         </a>
# <span class="b-statistics__date">
#                           July 01, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a780d16cf7eed44d">
#                           UFC Fight Night: Emmett vs. Topuria
#                         </a>
# <span class="b-statistics__date">
#                           June 24, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Jacksonville, Florida, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b9415726dc3ec526">
#                           UFC Fight Night: Vettori vs. Cannonier
#                         </a>
# <span class="b-statistics__date">
#                           June 17, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b6c6d1731ff00eeb">
#                           UFC 289: Nunes vs. Aldana
#                         </a>
# <span class="b-statistics__date">
#                           June 10, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Vancouver, British Columbia, Canada
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/7abe471b61725980">
#                           UFC Fight Night: Kara-France vs. Albazi
#                         </a>
# <span class="b-statistics__date">
#                           June 03, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/6f812143641ceff8">
#                           UFC Fight Night: Dern vs. Hill
#                         </a>
# <span class="b-statistics__date">
#                           May 20, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/901cddcbfa079097">
#                           UFC Fight Night: Rozenstruik vs. Almeida
#                         </a>
# <span class="b-statistics__date">
#                           May 13, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Charlotte, North Carolina, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/3c6976f8182d9527">
#                           UFC 288: Sterling vs. Cejudo
#                         </a>
# <span class="b-statistics__date">
#                           May 06, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Newark, New Jersey, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/51b1e2fd9872005b">
#                           UFC Fight Night: Song vs. Simon
#                         </a>
# <span class="b-statistics__date">
#                           April 29, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/6fb1ba67bef41b37">
#                           UFC Fight Night: Pavlovich vs. Blaydes
#                         </a>
# <span class="b-statistics__date">
#                           April 22, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/15b1b21cd743d652">
#                           UFC Fight Night: Holloway vs. Allen
#                         </a>
# <span class="b-statistics__date">
#                           April 15, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Kansas City, Missouri, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/3dc3022232b79c7a">
#                           UFC 287: Pereira vs. Adesanya 2
#                         </a>
# <span class="b-statistics__date">
#                           April 08, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Miami, Florida, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/aec273fcb765330d">
#                           UFC Fight Night: Vera vs. Sandhagen
#                         </a>
# <span class="b-statistics__date">
#                           March 25, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     San Antonio, Texas, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/e4bb7e483c4ad318">
#                           UFC 286: Edwards vs. Usman 3
#                         </a>
# <span class="b-statistics__date">
#                           March 18, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     London, England, United Kingdom
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/35080a7f406f9ab3">
#                           UFC Fight Night: Yan vs. Dvalishvili
#                         </a>
# <span class="b-statistics__date">
#                           March 11, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1ccff7f0cfdf85eb">
#                           UFC 285: Jones vs. Gane
#                         </a>
# <span class="b-statistics__date">
#                           March 04, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/806975e1b4f47b27">
#                           UFC Fight Night: Muniz vs. Allen
#                         </a>
# <span class="b-statistics__date">
#                           February 25, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/f21a3d68fb9df387">
#                           UFC Fight Night: Andrade vs. Blanchfield
#                         </a>
# <span class="b-statistics__date">
#                           February 18, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/01dd4cdc2446f665">
#                           UFC 284: Makhachev vs. Volkanovski
#                         </a>
# <span class="b-statistics__date">
#                           February 11, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Perth, Western Australia, Australia
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/d26394fc0e8e880a">
#                           UFC Fight Night: Lewis vs. Spivac
#                         </a>
# <span class="b-statistics__date">
#                           February 04, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/5717efc6f271cd52">
#                           UFC 283: Teixeira vs. Hill
#                         </a>
# <span class="b-statistics__date">
#                           January 21, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Rio de Janeiro, Rio de Janeiro, Brazil
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/2e2cdb6e9eb84bb9">
#                           UFC Fight Night: Strickland vs. Imavov
#                         </a>
# <span class="b-statistics__date">
#                           January 14, 2023
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/56ec58954158966a">
#                           UFC Fight Night: Cannonier vs. Strickland
#                         </a>
# <span class="b-statistics__date">
#                           December 17, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/f65a0eb902f9476b">
#                           UFC 282: Blachowicz vs. Ankalaev
#                         </a>
# <span class="b-statistics__date">
#                           December 10, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b23388ff8ac6637b">
#                           UFC Fight Night: Thompson vs. Holland
#                         </a>
# <span class="b-statistics__date">
#                           December 03, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Orlando, Florida, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/012fc7cd0779c09a">
#                           UFC Fight Night: Nzechukwu vs. Cutelaba
#                         </a>
# <span class="b-statistics__date">
#                           November 19, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b3b6e80b7d5f8f0d">
#                           UFC 281: Adesanya vs. Pereira
#                         </a>
# <span class="b-statistics__date">
#                           November 12, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     New York City, New York, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/756f45905fb20cb5">
#                           UFC Fight Night: Rodriguez vs. Lemos
#                         </a>
# <span class="b-statistics__date">
#                           November 05, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/be5aab761c40ef35">
#                           UFC Fight Night: Kattar vs. Allen
#                         </a>
# <span class="b-statistics__date">
#                           October 29, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/885e7f70dcac0007">
#                           UFC 280: Oliveira vs. Makhachev
#                         </a>
# <span class="b-statistics__date">
#                           October 22, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Abu Dhabi, Abu Dhabi, United Arab Emirates
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/49c29e57d4e2be6f">
#                           UFC Fight Night: Grasso vs. Araujo
#                         </a>
# <span class="b-statistics__date">
#                           October 15, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/4f670b7972fa0a2e">
#                           UFC Fight Night: Dern vs. Yan
#                         </a>
# <span class="b-statistics__date">
#                           October 01, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/8d477c3fbe001f9d">
#                           UFC Fight Night: Sandhagen vs. Song
#                         </a>
# <span class="b-statistics__date">
#                           September 17, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/93bf96be327fcd98">
#                           UFC 279: Diaz vs. Ferguson
#                         </a>
# <span class="b-statistics__date">
#                           September 10, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/00a905a4a4a2b071">
#                           UFC Fight Night: Gane vs. Tuivasa
#                         </a>
# <span class="b-statistics__date">
#                           September 03, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Paris, Ile-de-France, France
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/4f853e98886283cf">
#                           UFC 278: Usman vs. Edwards
#                         </a>
# <span class="b-statistics__date">
#                           August 20, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Salt Lake City, Utah, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a23e63184c65f5b8">
#                           UFC Fight Night: Vera vs. Cruz
#                         </a>
# <span class="b-statistics__date">
#                           August 13, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     San Diego, California, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/8f6a18831a120817">
#                           UFC Fight Night: Santos vs. Hill
#                         </a>
# <span class="b-statistics__date">
#                           August 06, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b0a6124751a56bc4">
#                           UFC 277: Pena vs. Nunes 2
#                         </a>
# <span class="b-statistics__date">
#                           July 30, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Dallas, Texas, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/319c15b8aac5bfde">
#                           UFC Fight Night: Blaydes vs. Aspinall
#                         </a>
# <span class="b-statistics__date">
#                           July 23, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     London, England, United Kingdom
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/8fd76e1b49c00ae2">
#                           UFC Fight Night: Ortega vs. Rodriguez
#                         </a>
# <span class="b-statistics__date">
#                           July 16, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Elmont, New York, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/31da66df48c0c1a0">
#                           UFC Fight Night: Dos Anjos vs. Fiziev
#                         </a>
# <span class="b-statistics__date">
#                           July 09, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/4a9e305633f3ef47">
#                           UFC 276: Adesanya vs. Cannonier
#                         </a>
# <span class="b-statistics__date">
#                           July 02, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/eb42d4febfafefd1">
#                           UFC Fight Night: Tsarukyan vs. Gamrot
#                         </a>
# <span class="b-statistics__date">
#                           June 25, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a0a680fe2f6cc8e6">
#                           UFC Fight Night: Kattar vs. Emmett
#                         </a>
# <span class="b-statistics__date">
#                           June 18, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Austin, Texas, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/3a24769a4855040a">
#                           UFC 275: Teixeira vs. Prochazka
#                         </a>
# <span class="b-statistics__date">
#                           June 11, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Kallang, Singapore
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/57591bbf1623574e">
#                           UFC Fight Night: Volkov vs. Rozenstruik
#                         </a>
# <span class="b-statistics__date">
#                           June 04, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a6c32678efd4f434">
#                           UFC Fight Night: Holm vs. Vieira
#                         </a>
# <span class="b-statistics__date">
#                           May 21, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/60ba33c3f555a7a3">
#                           UFC Fight Night: Blachowicz vs. Rakic
#                         </a>
# <span class="b-statistics__date">
#                           May 14, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/253d3f9e97ca149a">
#                           UFC 274: Oliveira vs. Gaethje
#                         </a>
# <span class="b-statistics__date">
#                           May 07, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Phoenix, Arizona, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/6bf5a7d3e081ade2">
#                           UFC Fight Night: Font vs. Vera
#                         </a>
# <span class="b-statistics__date">
#                           April 30, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/236a37d96d476164">
#                           UFC Fight Night: Lemos vs. Andrade
#                         </a>
# <span class="b-statistics__date">
#                           April 23, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/8753e125f4499816">
#                           UFC Fight Night: Luque vs. Muhammad
#                         </a>
# <span class="b-statistics__date">
#                           April 16, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/3a97fda0de6f1fa4">
#                           UFC 273: Volkanovski vs. The Korean Zombie
#                         </a>
# <span class="b-statistics__date">
#                           April 09, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Jacksonville, Florida, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1fac46d466abd5b8">
#                           UFC Fight Night: Blaydes vs. Daukaus
#                         </a>
# <span class="b-statistics__date">
#                           March 26, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Columbus, Ohio, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1d00756835ca67c9">
#                           UFC Fight Night: Volkov vs. Aspinall
#                         </a>
# <span class="b-statistics__date">
#                           March 19, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     London, England, United Kingdom
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1f9344211ca7fd60">
#                           UFC Fight Night: Santos vs. Ankalaev
#                         </a>
# <span class="b-statistics__date">
#                           March 12, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/75e0d3cc2262b732">
#                           UFC 272: Covington vs. Masvidal
#                         </a>
# <span class="b-statistics__date">
#                           March 05, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/f6a7b02c42e9fc5b">
#                           UFC Fight Night: Makhachev vs. Green
#                         </a>
# <span class="b-statistics__date">
#                           February 26, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/77940e45bc86208e">
#                           UFC Fight Night: Walker vs. Hill
#                         </a>
# <span class="b-statistics__date">
#                           February 19, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/cbb682f5fcc44bfc">
#                           UFC 271: Adesanya vs. Whittaker 2
#                         </a>
# <span class="b-statistics__date">
#                           February 12, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Houston, Texas, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/883922e5cd6d8473">
#                           UFC Fight Night: Hermansson vs. Strickland
#                         </a>
# <span class="b-statistics__date">
#                           February 05, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/335ad945324c3a2e">
#                           UFC 270: Ngannou vs. Gane
#                         </a>
# <span class="b-statistics__date">
#                           January 22, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Anaheim, California, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/f5585e675af7afd4">
#                           UFC Fight Night: Kattar vs. Chikadze
#                         </a>
# <span class="b-statistics__date">
#                           January 15, 2022
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/2a470ad41c22c25a">
#                           UFC Fight Night: Lewis vs. Daukaus
#                         </a>
# <span class="b-statistics__date">
#                           December 18, 2021
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/ef927e4fe2117ab8">
#                           UFC 269: Oliveira vs. Poirier
#                         </a>
# <span class="b-statistics__date">
#                           December 11, 2021
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/509697e08673d2e5">
#                           UFC Fight Night: Font vs. Aldo
#                         </a>
# <span class="b-statistics__date">
#                           December 04, 2021
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/c95fbc085e17a532">
#                           UFC Fight Night: Vieira vs. Tate
#                         </a>
# <span class="b-statistics__date">
#                           November 20, 2021
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b5abaa65f87938eb">
#                           UFC Fight Night: Holloway vs. Rodriguez
#                         </a>
# <span class="b-statistics__date">
#                           November 13, 2021
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Las Vegas, Nevada, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/48e093ea1f43a053">
#                           UFC 268: Usman vs. Covington 2
#                         </a>
# <span class="b-statistics__date">
#                           November 06, 2021
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     New York City, New York, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/3974fa35c917af1d">
#                           UFC 267: Blachowicz vs. Teixeira
#                         </a>
# <span class="b-statistics__date">
#                           October 30, 2021
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Abu Dhabi, Abu Dhabi, United Arab Emirates
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/8a9c6c4301f6d088">
#                           UFC Fight Night: Costa vs. Vettori
#                         </a>
# <span class="b-statistics__date">
#                           October 23, 2021
# ...
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/d2b1c1317a39f6c6">
#                           UFC 25: Ultimate Japan 3
#                         </a>
# <span class="b-statistics__date">
#                           April 14, 2000
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Tokyo, Japan
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/20ec0061400178ca">
#                           UFC 24: First Defense
#                         </a>
# <span class="b-statistics__date">
#                           March 10, 2000
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Lake Charles, Louisiana, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a8fa0c4e95512806">
#                           UFC 23: Ultimate Japan 2
#                         </a>
# <span class="b-statistics__date">
#                           November 19, 1999
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Chiba, Japan
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/afaad7d6a581e307">
#                           UFC 22: Only One Can be Champion
#                         </a>
# <span class="b-statistics__date">
#                           September 24, 1999
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Lake Charles, Louisiana, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1a1a4d7a29041d77">
#                           UFC 21: Return of the Champions
#                         </a>
# <span class="b-statistics__date">
#                           July 16, 1999
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Cedar Rapids, Iowa, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a7b48e18ca27795d">
#                           UFC 20: Battle for the Gold
#                         </a>
# <span class="b-statistics__date">
#                           May 07, 1999
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Birmingham, Alabama, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a220be6d41d6f97d">
#                           UFC 19: Ultimate Young Guns
#                         </a>
# <span class="b-statistics__date">
#                           March 05, 1999
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Bay St. Louis, Mississippi, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/c9bbf1a0285a8076">
#                           UFC 18: The Road to the Heavyweight Title
#                         </a>
# <span class="b-statistics__date">
#                           January 08, 1999
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     New Orleans, Louisiana, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/32a3025d5db456ae">
#                           UFC - Ultimate Brazil
#                         </a>
# <span class="b-statistics__date">
#                           October 16, 1998
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Sao Paulo, Brazil
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/4a01dc8376736ef5">
#                           UFC 17: Redemption
#                         </a>
# <span class="b-statistics__date">
#                           May 15, 1998
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Mobile, Alabama, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/749685d24e2cac50">
#                           UFC 16: Battle in the Bayou
#                         </a>
# <span class="b-statistics__date">
#                           March 13, 1998
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     New Orleans, Louisiana, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/29f935654825331b">
#                           UFC - Ultimate Japan
#                         </a>
# <span class="b-statistics__date">
#                           December 21, 1997
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Yokohama, Kanagawa, Japan
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/07a18ae55dfc3cd9">
#                           UFC 15: Collision Course
#                         </a>
# <span class="b-statistics__date">
#                           October 17, 1997
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Bay St. Louis, Mississippi, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/dc950d59dc590aca">
#                           UFC 14: Showdown
#                         </a>
# <span class="b-statistics__date">
#                           July 27, 1997
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Birmingham, Alabama, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/5bd533d50c8e7b8a">
#                           UFC 13: The Ultimate Force
#                         </a>
# <span class="b-statistics__date">
#                           May 30, 1997
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Augusta, Georgia, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/96eff1a628adcc7f">
#                           UFC 12: Judgement Day
#                         </a>
# <span class="b-statistics__date">
#                           February 07, 1997
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Dothan, Alabama, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/9b5b5a75523728f3">
#                           UFC - Ultimate Ultimate '96
#                         </a>
# <span class="b-statistics__date">
#                           December 07, 1996
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Birmingham, Alabama, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/6ceff86fae4f6b3b">
#                           UFC 11: The Proving Ground
#                         </a>
# <span class="b-statistics__date">
#                           September 20, 1996
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Augusta, Georgia, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/aee8eecfc4bfb1e7">
#                           UFC 10: The Tournament
#                         </a>
# <span class="b-statistics__date">
#                           July 12, 1996
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Birmingham, Alabama, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a390eb8a9b2df298">
#                           UFC 9: Motor City Madness
#                         </a>
# <span class="b-statistics__date">
#                           May 17, 1996
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Detroit, Michigan, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b63e800c18e011b5">
#                           UFC 8: David vs Goliath
#                         </a>
# <span class="b-statistics__date">
#                           February 16, 1996
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     San Juan, Puerto Rico
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/31bbd46d57dfbcb7">
#                           UFC - Ultimate Ultimate '95
#                         </a>
# <span class="b-statistics__date">
#                           December 16, 1995
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Denver, Colorado, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/5af480a3b2e1726b">
#                           UFC 7: The Brawl in Buffalo
#                         </a>
# <span class="b-statistics__date">
#                           September 08, 1995
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Buffalo, New York, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1c3f5e85b59ec710">
#                           UFC 6: Clash of the Titans
#                         </a>
# <span class="b-statistics__date">
#                           July 14, 1995
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Casper, Wyoming, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/dedc3bb440d09554">
#                           UFC 5: The Return of the Beast
#                         </a>
# <span class="b-statistics__date">
#                           April 07, 1995
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Charlotte, North Carolina, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/b60391da771deefe">
#                           UFC 4: Revenge of the Warriors
#                         </a>
# <span class="b-statistics__date">
#                           December 16, 1994
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Tulsa, Oklahoma, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/1a49e0670dfaca31">
#                           UFC 3: The American Dream
#                         </a>
# <span class="b-statistics__date">
#                           September 09, 1994
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Charlotte, North Carolina, USA
#                   </td>
# </tr>
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col">
# <i class="b-statistics__table-content">
# <a class="b-link b-link_style_black" href="http://www.ufcstats.com/event-details/a6a9ab5a824e8f66">
#                           UFC 2: No Way Out
#                         </a>
# <span class="b-statistics__date">
#                           March 11, 1994
#                         </span>
# </i>
# </td>
# <td class="b-statistics__table-col b-statistics__table-col_style_big-top-padding">
#                     Denver, Colorado, USA
#                   </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Tratamento

# %% [markdown]
# Para poder utilizar estes dados na nossa analise e modelagem, primeiro é necessario transformar esta tabela html em um data frame pandas.

# %%
# Alterando função para transformar tabela em dataframe
def get_events():
    """
        Função que retorna a tabela de eventos realizados no ufc em formato html
    """
    # Link de acesso para pagina
    URL = "http://www.ufcstats.com/statistics/events/completed?page=all"


    # Realizando o request para o site
    response = requests.get(URL)
    response.raise_for_status()

    # Obtendo pagina completa em html
    soup = BeautifulSoup(response.content, "html.parser")

    # Encontrando a tabela com a classe especificada
    table = soup.find("table", class_="b-statistics__table-events")

    # Transformando tabela de html para dataframe pandas ou retornando erro se não encontrar a tabela
    if table:
        # Extraindo cabeçalho
        header = [th.text.strip() for th in table.find('thead').find_all('th')]

        # Extraindo as linhas
        rows = table.find('tbody').find_all('tr')
        table_data = [[col.text.strip() for col in row.find_all('td')] for row in rows]

        # Convertendo em dataframe
        df_bruto = pd.DataFrame(table_data[1:], columns=header) #Obs: Não considera a primeira linha

        return df_bruto
    else:
        return print("Não foi possível encontrar a tabela desejada na página.")

# %% [markdown]
# Com as alterações feitas na função get_events(), ela agora retorna o dataframe em sua forma original, sem qualquer processamento. Se a tabela não for localizada, uma mensagem de erro é exibida.
#
# `Observação:`
#     É importante mencionar que há um leve pré-processamento ao criar o dataframe, onde a primeira linha é ignorada. Isso ocorre porque, no formato atual da tabela no dia em que este script foi feito, essa linha é consistentemente nula.

# %%
# Visualizando o retorno
df = get_events()

df
# Out:
#                                              Name/date  \
# 0    UFC 293: Adesanya vs. Strickland\n            ...
# 1    UFC Fight Night: Gane vs. Spivac\n            ...
# 2    UFC Fight Night: Holloway vs. The Korean Zombi...
# 3    UFC 292: Sterling vs. O'Malley\n              ...
# 4    UFC Fight Night: Luque vs. Dos Anjos\n        ...
# ..                                                 ...
# 657  UFC 6: Clash of the Titans\n                  ...
# 658  UFC 5: The Return of the Beast\n              ...
# 659  UFC 4: Revenge of the Warriors\n              ...
# 660  UFC 3: The American Dream\n                   ...
# 661  UFC 2: No Way Out\n                        \n\...
#
#                                Location
# 0    Sydney, New South Wales, Australia
# 1          Paris, Ile-de-France, France
# 2                    Kallang, Singapore
# 3            Boston, Massachusetts, USA
# 4                Las Vegas, Nevada, USA
# ..                                  ...
# 657                Casper, Wyoming, USA
# 658      Charlotte, North Carolina, USA
# 659                Tulsa, Oklahoma, USA
# 660      Charlotte, North Carolina, USA
# 661               Denver, Colorado, USA
#
# [662 rows x 2 columns]

# %% [markdown]
# Ao observar o dataframe bruto, notamos que ele tem duas colunas. Mas, ao examinar o conteúdo da primeira coluna, identificamos duas informações chave: o nome do evento e a data. Ao tratar essas informações, poderemos reestruturar o dataframe de modo que apresente colunas distintas para o nome do evento e sua respectiva data.
#
# Para entender melhor o processo de tratamento, será analisada a string:

# %%
# Criando variavel e armazenando a primeira linha
string_name_date = df['Name/date'][0]

string_name_date = string_name_date.strip().split("\n")[-1].strip()

string_name_date
# Out:
# 'September 09, 2023'

# %% [markdown]
# Realizando este tratamento, temos a data.

# %%
# Transformando em datetime
datetime_name_date = pd.to_datetime(string_name_date).date()

display(datetime_name_date)
type(datetime_name_date)
# Out:
# datetime.date(2023, 9, 9)
# datetime.date

# %% [markdown]
# Com estes tratamentos, temos duas novas colunas com a data e nome do evento.

# %%
# Aplicando no dataframe para visualizar o resultado

# Ajustando o evento
df['event'] = df['Name/date'].str.split("\n")

df['event'] = df['event'].apply(lambda x: x[0])

# Ajustando data
df['date'] = df['Name/date'].apply(lambda x: x.split("\n")[-1].strip())

df['date'] = pd.to_datetime(df['date'])

df
# Out:
#                                              Name/date  \
# 0    UFC 293: Adesanya vs. Strickland\n            ...
# 1    UFC Fight Night: Gane vs. Spivac\n            ...
# 2    UFC Fight Night: Holloway vs. The Korean Zombi...
# 3    UFC 292: Sterling vs. O'Malley\n              ...
# 4    UFC Fight Night: Luque vs. Dos Anjos\n        ...
# ..                                                 ...
# 657  UFC 6: Clash of the Titans\n                  ...
# 658  UFC 5: The Return of the Beast\n              ...
# 659  UFC 4: Revenge of the Warriors\n              ...
# 660  UFC 3: The American Dream\n                   ...
# 661  UFC 2: No Way Out\n                        \n\...
#
#                                Location  \
# 0    Sydney, New South Wales, Australia
# 1          Paris, Ile-de-France, France
# 2                    Kallang, Singapore
# 3            Boston, Massachusetts, USA
# 4                Las Vegas, Nevada, USA
# ..                                  ...
# 657                Casper, Wyoming, USA
# 658      Charlotte, North Carolina, USA
# 659                Tulsa, Oklahoma, USA
# 660      Charlotte, North Carolina, USA
# 661               Denver, Colorado, USA
#
#                                                event       date
# 0                   UFC 293: Adesanya vs. Strickland 2023-09-09
# 1                   UFC Fight Night: Gane vs. Spivac 2023-09-02
# 2    UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26
# 3                     UFC 292: Sterling vs. O'Malley 2023-08-19
# 4               UFC Fight Night: Luque vs. Dos Anjos 2023-08-12
# ..                                               ...        ...
# 657                       UFC 6: Clash of the Titans 1995-07-14
# 658                   UFC 5: The Return of the Beast 1995-04-07
# 659                   UFC 4: Revenge of the Warriors 1994-12-16
# 660                        UFC 3: The American Dream 1994-09-09
# 661                                UFC 2: No Way Out 1994-03-11
#
# [662 rows x 4 columns]

# %% [markdown]
# Após estas modificações, podemos retirar a coluna Name/date

# %%
# Retirando coluna Name/date

df = df.drop(columns=["Name/date"])

df
# Out:
#                                Location  \
# 0    Sydney, New South Wales, Australia
# 1          Paris, Ile-de-France, France
# 2                    Kallang, Singapore
# 3            Boston, Massachusetts, USA
# 4                Las Vegas, Nevada, USA
# ..                                  ...
# 657                Casper, Wyoming, USA
# 658      Charlotte, North Carolina, USA
# 659                Tulsa, Oklahoma, USA
# 660      Charlotte, North Carolina, USA
# 661               Denver, Colorado, USA
#
#                                                event       date
# 0                   UFC 293: Adesanya vs. Strickland 2023-09-09
# 1                   UFC Fight Night: Gane vs. Spivac 2023-09-02
# 2    UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26
# 3                     UFC 292: Sterling vs. O'Malley 2023-08-19
# 4               UFC Fight Night: Luque vs. Dos Anjos 2023-08-12
# ..                                               ...        ...
# 657                       UFC 6: Clash of the Titans 1995-07-14
# 658                   UFC 5: The Return of the Beast 1995-04-07
# 659                   UFC 4: Revenge of the Warriors 1994-12-16
# 660                        UFC 3: The American Dream 1994-09-09
# 661                                UFC 2: No Way Out 1994-03-11
#
# [662 rows x 3 columns]

# %% [markdown]
# Adicionalmente ao tratamento já mencionado, faremos uma modificação na coluna "location". Separando a cidade e o pais em duas colunas distintas.

# %%
# Criando string para demonstração do código
string_location = df['Location'][0]

string_location = string_location.split(",")

string_location
# Out:
# ['Sydney', ' New South Wales', ' Australia']

# %% [markdown]
# Ao usar a função "split", conseguimos criar colunas para a cidade, estado e país. É importante destacar que algumas entradas na coluna original não apresentam o estado. Por conta disto, foi implementada uma condição que insere valores nulos quando o estado não está especificado.

# %%
# Aplicando modificações no data frame
df['city'] = df['Location'].apply(lambda x: x.split(",")[0].strip())

df['country'] = df['Location'].apply(lambda x: x.split(",")[-1].strip())

df['state'] = df['Location'].apply(lambda x: x.split(",")[1].strip() if len(x.split(",")) == 3 else np.nan)

df
# Out:
#                                Location  \
# 0    Sydney, New South Wales, Australia
# 1          Paris, Ile-de-France, France
# 2                    Kallang, Singapore
# 3            Boston, Massachusetts, USA
# 4                Las Vegas, Nevada, USA
# ..                                  ...
# 657                Casper, Wyoming, USA
# 658      Charlotte, North Carolina, USA
# 659                Tulsa, Oklahoma, USA
# 660      Charlotte, North Carolina, USA
# 661               Denver, Colorado, USA
#
#                                                event       date       city  \
# 0                   UFC 293: Adesanya vs. Strickland 2023-09-09     Sydney
# 1                   UFC Fight Night: Gane vs. Spivac 2023-09-02      Paris
# 2    UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26    Kallang
# 3                     UFC 292: Sterling vs. O'Malley 2023-08-19     Boston
# 4               UFC Fight Night: Luque vs. Dos Anjos 2023-08-12  Las Vegas
# ..                                               ...        ...        ...
# 657                       UFC 6: Clash of the Titans 1995-07-14     Casper
# 658                   UFC 5: The Return of the Beast 1995-04-07  Charlotte
# 659                   UFC 4: Revenge of the Warriors 1994-12-16      Tulsa
# 660                        UFC 3: The American Dream 1994-09-09  Charlotte
# 661                                UFC 2: No Way Out 1994-03-11     Denver
#
#        country            state
# 0    Australia  New South Wales
# 1       France    Ile-de-France
# 2    Singapore              NaN
# 3          USA    Massachusetts
# 4          USA           Nevada
# ..         ...              ...
# 657        USA          Wyoming
# 658        USA   North Carolina
# 659        USA         Oklahoma
# 660        USA   North Carolina
# 661        USA         Colorado
#
# [662 rows x 6 columns]

# %% [markdown]
# Após estas modificações, podemos retirar a coluna Location e chegaremos no dataframe final.

# %%
# Retirando a coluna Location
df = df.drop(columns=["Location"])

df
# Out:
#                                                event       date       city  \
# 0                   UFC 293: Adesanya vs. Strickland 2023-09-09     Sydney
# 1                   UFC Fight Night: Gane vs. Spivac 2023-09-02      Paris
# 2    UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26    Kallang
# 3                     UFC 292: Sterling vs. O'Malley 2023-08-19     Boston
# 4               UFC Fight Night: Luque vs. Dos Anjos 2023-08-12  Las Vegas
# ..                                               ...        ...        ...
# 657                       UFC 6: Clash of the Titans 1995-07-14     Casper
# 658                   UFC 5: The Return of the Beast 1995-04-07  Charlotte
# 659                   UFC 4: Revenge of the Warriors 1994-12-16      Tulsa
# 660                        UFC 3: The American Dream 1994-09-09  Charlotte
# 661                                UFC 2: No Way Out 1994-03-11     Denver
#
#        country            state
# 0    Australia  New South Wales
# 1       France    Ile-de-France
# 2    Singapore              NaN
# 3          USA    Massachusetts
# 4          USA           Nevada
# ..         ...              ...
# 657        USA          Wyoming
# 658        USA   North Carolina
# 659        USA         Oklahoma
# 660        USA   North Carolina
# 661        USA         Colorado
#
# [662 rows x 5 columns]

# %% [markdown]
# Após a etapa de webscraping e os devidos ajustes, este é o formato do dataframe.
#
# Considerando a intenção é tambem poder usar esta tabela em um banco de dados relacional, adicionaremos uma coluna para as chaves únicas de cada evento.
#
#
# Estrutura das chaves:
#
# <center>EVEXXXX</center>
#
#
# Onde "EVE" indica a origem da tabela de eventos e "XXXX" é o número sequencial do evento. Por exemplo, o código EVE0001 denota o primeiro evento listado na tabela do site em questão.

# %%
# Criando range com o index invertido

inverted_index = df.index[::-1] + 1

# Criando a chave primaria no formato explicado

df['event_id'] = ["EVE" + f"{index:04}" for index in inverted_index]

df
# Out:
#                                                event       date       city  \
# 0                   UFC 293: Adesanya vs. Strickland 2023-09-09     Sydney
# 1                   UFC Fight Night: Gane vs. Spivac 2023-09-02      Paris
# 2    UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26    Kallang
# 3                     UFC 292: Sterling vs. O'Malley 2023-08-19     Boston
# 4               UFC Fight Night: Luque vs. Dos Anjos 2023-08-12  Las Vegas
# ..                                               ...        ...        ...
# 657                       UFC 6: Clash of the Titans 1995-07-14     Casper
# 658                   UFC 5: The Return of the Beast 1995-04-07  Charlotte
# 659                   UFC 4: Revenge of the Warriors 1994-12-16      Tulsa
# 660                        UFC 3: The American Dream 1994-09-09  Charlotte
# 661                                UFC 2: No Way Out 1994-03-11     Denver
#
#        country            state event_id
# 0    Australia  New South Wales  EVE0662
# 1       France    Ile-de-France  EVE0661
# 2    Singapore              NaN  EVE0660
# 3          USA    Massachusetts  EVE0659
# 4          USA           Nevada  EVE0658
# ..         ...              ...      ...
# 657        USA          Wyoming  EVE0005
# 658        USA   North Carolina  EVE0004
# 659        USA         Oklahoma  EVE0003
# 660        USA   North Carolina  EVE0002
# 661        USA         Colorado  EVE0001
#
# [662 rows x 6 columns]

# %% [markdown]
# O ultimo tratamento é em reajustar a ordem das colunas.

# %%
# Reordenando colunas do dataframe

df = df[["event_id", "event", "date","city", "state", "country"]]

df
# Out:
#     event_id                                            event       date  \
# 0    EVE0662                 UFC 293: Adesanya vs. Strickland 2023-09-09
# 1    EVE0661                 UFC Fight Night: Gane vs. Spivac 2023-09-02
# 2    EVE0660  UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26
# 3    EVE0659                   UFC 292: Sterling vs. O'Malley 2023-08-19
# 4    EVE0658             UFC Fight Night: Luque vs. Dos Anjos 2023-08-12
# ..       ...                                              ...        ...
# 657  EVE0005                       UFC 6: Clash of the Titans 1995-07-14
# 658  EVE0004                   UFC 5: The Return of the Beast 1995-04-07
# 659  EVE0003                   UFC 4: Revenge of the Warriors 1994-12-16
# 660  EVE0002                        UFC 3: The American Dream 1994-09-09
# 661  EVE0001                                UFC 2: No Way Out 1994-03-11
#
#           city            state    country
# 0       Sydney  New South Wales  Australia
# 1        Paris    Ile-de-France     France
# 2      Kallang              NaN  Singapore
# 3       Boston    Massachusetts        USA
# 4    Las Vegas           Nevada        USA
# ..         ...              ...        ...
# 657     Casper          Wyoming        USA
# 658  Charlotte   North Carolina        USA
# 659      Tulsa         Oklahoma        USA
# 660  Charlotte   North Carolina        USA
# 661     Denver         Colorado        USA
#
# [662 rows x 6 columns]

# %% [markdown]
# Reajustando função final:

# %%
def get_events(bruto=False):
    """
    Função que retorna o data frame com todos os eventos realizados pelo UFC e armazenados no site UFCstats.
    """
    # Link de acesso para pagina
    URL = "http://www.ufcstats.com/statistics/events/completed?page=all"


    # Realizando o request para o site 
    response = requests.get(URL)
    response.raise_for_status()

    # Obtendo pagina completa em html
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Encontrando a tabela com a classe especificada
    table = soup.find("table", class_="b-statistics__table-events")

    # Transformando tabela de html para dataframe pandas ou retornando erro se não encontrar a tabela
    if table:
        # Extraindo cabeçalho
        header = [th.text.strip() for th in table.find('thead').find_all('th')]

        # Extraindo as linhas
        rows = table.find('tbody').find_all('tr')
        table_data = [[col.text.strip() for col in row.find_all('td')] for row in rows]

        # Convertendo em dataframe
        df_bruto = pd.DataFrame(table_data[1:], columns=header) #Obs: Não considera a primeira linha

    else:
        return print("Não foi possível encontrar a tabela desejada na página.")


    if bruto:
        return df_bruto

    """
    A parte do código abaixo é dedicata ao tratamento do df_bruto para os parametros pré estabelecidos no arquivo note_get_events.ipynb.
    """

    # Criando o dataframe final
    df_final = df_bruto.copy()

    # Ajustando coluna evento
    df_final['event'] = df_final['Name/date'].str.split("\n")
    df_final['event'] = df_final['event'].apply(lambda x: x[0])

    # Ajustando data
    df_final['date'] = df_final['Name/date'].apply(lambda x: x.split("\n")[-1].strip())
    df_final['date'] = pd.to_datetime(df_final['date'])

    # Retirando coluna Name/date
    df_final = df_final.drop(columns=["Name/date"])

    # Criando colunas de cidade, estado e pais
    # Cidade
    df_final['city'] = df_final['Location'].apply(lambda x: x.split(",")[0].strip())

    # Estado
    df_final['state'] = df_final['Location'].apply(lambda x: x.split(",")[1].strip() if len(x.split(",")) == 3 else np.nan)

    # Pais
    df_final['country'] = df_final['Location'].apply(lambda x: x.split(",")[-1].strip())

    # Removendo a coluna Location
    df_final = df_final.drop(columns=["Location"])


    """
    A parte do código a seguir, cria uma primary key para a tabela de evetos, para mais detalhes olhar o arquivo documentado note_get_events.ipynb
    """

    # Criando range com o index invertido
    inverted_index = df_final.index[::-1] + 1

    # Criando a chave primaria no formato EVEXXXX
    df_final['event_id'] = ["EVE" + f"{index:04}" for index in inverted_index]

    """
    Como ultimo tratamento, as colunas serão reorganizadas
    """
    df_final = df_final[["event_id", "event", "date","city", "state", "country"]]

    return df_final

# %% [markdown]
# ## Dicas de uso

# %% [markdown]
# - Obtendo dataframe:

# %%
# Criando dataframe de eventos utilizando a função
df_events = get_events()

df_events
# Out:
#     event_id                                            event       date  \
# 0    EVE0663         UFC Fight Night: Grasso vs. Shevchenko 2 2023-09-16
# 1    EVE0662                 UFC 293: Adesanya vs. Strickland 2023-09-09
# 2    EVE0661                 UFC Fight Night: Gane vs. Spivac 2023-09-02
# 3    EVE0660  UFC Fight Night: Holloway vs. The Korean Zombie 2023-08-26
# 4    EVE0659                   UFC 292: Sterling vs. O'Malley 2023-08-19
# ..       ...                                              ...        ...
# 658  EVE0005                       UFC 6: Clash of the Titans 1995-07-14
# 659  EVE0004                   UFC 5: The Return of the Beast 1995-04-07
# 660  EVE0003                   UFC 4: Revenge of the Warriors 1994-12-16
# 661  EVE0002                        UFC 3: The American Dream 1994-09-09
# 662  EVE0001                                UFC 2: No Way Out 1994-03-11
#
#           city            state    country
# 0    Las Vegas           Nevada        USA
# 1       Sydney  New South Wales  Australia
# 2        Paris    Ile-de-France     France
# 3      Kallang              NaN  Singapore
# 4       Boston    Massachusetts        USA
# ..         ...              ...        ...
# 658     Casper          Wyoming        USA
# 659  Charlotte   North Carolina        USA
# 660      Tulsa         Oklahoma        USA
# 661  Charlotte   North Carolina        USA
# 662     Denver         Colorado        USA
#
# [663 rows x 6 columns]

# %% [markdown]
# - Obtendo Dataframe Bruto

# %%
# Obtendo dataframe bruto, sem processamento
df_bruto = get_events(bruto=True)
df_bruto
# Out:
#                                              Name/date  \
# 0    UFC Fight Night: Grasso vs. Shevchenko 2\n    ...
# 1    UFC 293: Adesanya vs. Strickland\n            ...
# 2    UFC Fight Night: Gane vs. Spivac\n            ...
# 3    UFC Fight Night: Holloway vs. The Korean Zombi...
# 4    UFC 292: Sterling vs. O'Malley\n              ...
# ..                                                 ...
# 658  UFC 6: Clash of the Titans\n                  ...
# 659  UFC 5: The Return of the Beast\n              ...
# 660  UFC 4: Revenge of the Warriors\n              ...
# 661  UFC 3: The American Dream\n                   ...
# 662  UFC 2: No Way Out\n                        \n\...
#
#                                Location
# 0                Las Vegas, Nevada, USA
# 1    Sydney, New South Wales, Australia
# 2          Paris, Ile-de-France, France
# 3                    Kallang, Singapore
# 4            Boston, Massachusetts, USA
# ..                                  ...
# 658                Casper, Wyoming, USA
# 659      Charlotte, North Carolina, USA
# 660                Tulsa, Oklahoma, USA
# 661      Charlotte, North Carolina, USA
# 662               Denver, Colorado, USA
#
# [663 rows x 2 columns]

# %% [markdown]
# ## Atualizações

# %% [markdown]
# Sem atualizações até o momento.
